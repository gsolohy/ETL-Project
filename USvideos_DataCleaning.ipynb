# %%
#Extraction: Data sets of interest youtube. 
#resources from https://www.kaggle.com/datasnaek/youtube-new 
#2 CSV files:

# %%
#Dependencies 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
USvideos_data = pd.read_csv('USvideos.csv')
USvideos_data.head()
# Out:
#       video_id trending_date  \
# 0  1ZAPwfrtAFY      17.13.11
# 1  5qpjK5DgCt4      17.13.11
# 2  puqaWrEC7tY      17.13.11
# 3  d380meD0W0M      17.13.11
# 4  nc99ccSXST0      17.13.11
#
#                                                title          channel_title  \
# 0  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 1  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 2                   Nickleback Lyrics: Real or Fake?  Good Mythical Morning
# 3                           I Dare You: GOING BALD!?               nigahiga
# 4                5 Ice Cream Gadgets put to the Test     CrazyRussianHacker
#
#    category_id              publish_time  \
# 0           24  2017-11-13T07:30:00.000Z
# 1           23  2017-11-12T19:05:24.000Z
# 2           24  2017-11-13T11:00:04.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           28  2017-11-12T21:50:37.000Z
#
# ...

# %%
#View the headers
USvideos_data.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
#Verify the drop rows
USvideos_data.count()
# Out:
# video_id                  200
# trending_date             200
# title                     200
# channel_title             200
# category_id               200
# publish_time              200
# tags                      200
# views                     200
# likes                     200
# dislikes                  200
# comment_count             200
# thumbnail_link            200
# comments_disabled         200
# ratings_disabled          200
# video_error_or_removed    200
# description               197
# dtype: int64

# %%
USvideos_data.describe()
# Out:
#        category_id         views         likes      dislikes  comment_count
# count   200.000000  2.000000e+02  2.000000e+02    200.000000     200.000000
# mean     19.180000  9.554945e+05  3.759931e+04   1398.295000    3398.300000
# std       7.860441  2.726132e+06  1.417012e+05   3979.344076   11689.329648
# min       1.000000  7.310000e+02  0.000000e+00      0.000000       0.000000
# 25%      10.000000  8.547000e+04  1.892250e+03     72.000000     242.750000
# 50%      23.000000  2.702765e+05  6.688000e+03    218.500000     841.500000
# 75%      25.000000  8.266188e+05  2.003150e+04    987.750000    1796.500000
# max      29.000000  3.155392e+07  1.604674e+06  41767.000000  124505.000000

# %%
USvideos_data['channel_title'].value_counts()
# Out:
# Jordan Hanz                                1
# Kitten Lady                                1
# earMUSIC                                   1
# Nintendo                                   1
# SigridVEVO                                 1
# Vogue                                      1
# Lietuvos Futbolo Rinktinės Archyvas        1
# Sara Dietschy                              1
# Bon Appétit                                1
# Sailor J                                   1
# Chris and Jack                             1
# Business Insider                           1
# It's Okay To Be Smart                      1
# Life Noggin                                1
# Stewart Brand                              1
# NBA Highlights · YouTube                   1
# Mayo Clinic                                1
# Liza Koshy                                 1
# Alabama Football                           1
# Alicia Keys                                1
# FoxSearchlight                             1
# ...

# %%
# Identify incomplete rows
USvideos_data.count()
# Out:
# video_id                  200
# trending_date             200
# title                     200
# channel_title             200
# category_id               200
# publish_time              200
# tags                      200
# views                     200
# likes                     200
# dislikes                  200
# comment_count             200
# thumbnail_link            200
# comments_disabled         200
# ratings_disabled          200
# video_error_or_removed    200
# description               197
# dtype: int64

# %%
# The Amount column is the wrong data type. It should be numeric.
USvideos_data.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-6fce3d127cdd> in <module>
# ----> 1 pd.Index(USvideos.trending_date.is_monotonic)
#
# NameError: name 'USvideos' is not defined
