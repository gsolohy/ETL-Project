# %%
#import dependencies 
import pandas as pd
import numpy as np
import os

# %%
#load the csv files
CAvideos = 'CAvideos.csv'
USvideos = 'USvideos.csv'

# %%
#read the csv in pandas 
df0 = pd.read_csv('CAvideos.csv')
df1 = pd.read_csv('USvideos.csv')

# %%
#Print the csv heading limit to 3 rows
df0.head(3)
# Out:
#       video_id trending_date                                        title  \
# 0  n1WpP7iowLc      17.13.11   Eminem - Walk On Water (Audio) ft. Beyoncé
# 1  2Vv-BfVoq4g      17.13.11  Ed Sheeran - Perfect (Official Music Video)
# 2  d380meD0W0M      17.13.11                     I Dare You: GOING BALD!?
#
#   channel_title  category_id              publish_time  \
# 0    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1    Ed Sheeran           10  2017-11-09T11:04:14.000Z
# 2      nigahiga           24  2017-11-12T18:01:41.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  15826458   765725
# 1  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  31553923  1604688
# 2  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   1867990   123936
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     41768         124505  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# ...

# %%
#join the csv files 
filenames = ['CAvideos.csv', 'USvideos.csv']
dataframes = []
for f in filenames:
    dataframes.append(pd.read_csv(f))

# %%
filenames = ['CAvideos.csv', 'USvideos.csv']
dataframes = [pd.read_csv(f) for f in filenames]

# %%
print (filenames)
# Out:
# ['CAvideos.csv', 'USvideos.csv']

# %%
# Merge the two CSV files together are rename as Output 
join = pd.concat(dataframes)

# %%
print(dataframes)
# Out:
# [        video_id trending_date  \
# 0    n1WpP7iowLc      17.13.11
# 1    2Vv-BfVoq4g      17.13.11
# 2    d380meD0W0M      17.13.11
# 3    5qpjK5DgCt4      17.13.11
# 4    H1KBHFXm2Bg      17.13.11
# 5    JzCsM1vtn78      17.13.11
# 6    7MxiQ4v0EnE      17.13.11
# 7    0yIWz1XEeyc      17.13.11
# 8    FyZMnhUtLfE      17.13.11
# 9    AS9-ITLhQxo      17.13.11
# 10   43sm-QwLcx4      17.13.11
# 11   U3xLOo-CNwo      17.13.11
# 12   LUzsOyWp9lw      17.13.11
# 13   8NHA23f7LvU      17.13.11
# 14   gifPYwArCVQ      17.13.11
# 15   nc99ccSXST0      17.13.11
# 16   eAyxMv4IBH8      17.13.11
# 17   _uM5kFfkhB8      17.13.11
# 18   6H3wVsceoS0      17.13.11
# 19   ohACdnWapcY      17.13.11
# 20   PRlmRnU9qts      17.13.11
# 21   V4Uuxg6jmbo      17.13.11
# 22   kzwfHumJyYc      17.13.11
# 23   JwboxqDylgg      17.13.11
# 24   7779JdxVAg0      17.13.11
# 25   wuf2KinLxZ8      17.13.11
# 26   WuTFI5qftCE      17.13.11
# 27   exMNBvwCfRY      17.13.11
# 28   GBVxEpQr8R8      17.13.11
# ...

# %%
join.to_csv("output.csv")

# %%
Combine_data = pd.read_csv('output.csv', index_col=0)
Combine_data.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.13.11
# 1  2Vv-BfVoq4g      17.13.11
# 2  d380meD0W0M      17.13.11
# 3  5qpjK5DgCt4      17.13.11
# 4  H1KBHFXm2Bg      17.13.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
# 2                           I Dare You: GOING BALD!?      nigahiga
# 3  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 4    21 Savage - Bank Account (Official Music Video)     21 Savage
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           10  2017-11-09T11:04:14.000Z
# 2           24  2017-11-12T18:01:41.000Z
# 3           23  2017-11-12T19:05:24.000Z
# 4           10  2017-11-10T19:00:02.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
#View the headers
Combine_data.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
#Verify the drop rows
Combine_data.count()
# Out:
# video_id                  399
# trending_date             399
# title                     399
# channel_title             399
# category_id               399
# publish_time              399
# tags                      399
# views                     399
# likes                     399
# dislikes                  399
# comment_count             399
# thumbnail_link            399
# comments_disabled         399
# ratings_disabled          399
# video_error_or_removed    399
# description               390
# dtype: int64

# %%
Combine_data.describe()
# Out:
#        category_id         views         likes       dislikes  comment_count
# count   399.000000  3.990000e+02  3.990000e+02     399.000000     399.000000
# mean     19.736842  1.055786e+06  4.081638e+04    1810.929825    4037.478697
# std       7.554055  2.766263e+06  1.387237e+05    8789.677131   12317.136160
# min       1.000000  7.310000e+02  0.000000e+00       0.000000       0.000000
# 25%      17.000000  1.095415e+05  1.973000e+03      85.000000     268.500000
# 50%      23.000000  2.999430e+05  7.029000e+03     280.000000     974.000000
# 75%      24.000000  8.918180e+05  2.547650e+04    1093.000000    2494.500000
# max      43.000000  3.155392e+07  1.604688e+06  158956.000000  124505.000000

# %%
# The Amount column is the wrong data type. It should be numeric.
Combine_data.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
Combine_data.info
# Out:
# <bound method DataFrame.info of         video_id trending_date  \
# 0    n1WpP7iowLc      17.13.11
# 1    2Vv-BfVoq4g      17.13.11
# 2    d380meD0W0M      17.13.11
# 3    5qpjK5DgCt4      17.13.11
# 4    H1KBHFXm2Bg      17.13.11
# 5    JzCsM1vtn78      17.13.11
# 6    7MxiQ4v0EnE      17.13.11
# 7    0yIWz1XEeyc      17.13.11
# 8    FyZMnhUtLfE      17.13.11
# 9    AS9-ITLhQxo      17.13.11
# 10   43sm-QwLcx4      17.13.11
# 11   U3xLOo-CNwo      17.13.11
# 12   LUzsOyWp9lw      17.13.11
# 13   8NHA23f7LvU      17.13.11
# 14   gifPYwArCVQ      17.13.11
# 15   nc99ccSXST0      17.13.11
# 16   eAyxMv4IBH8      17.13.11
# 17   _uM5kFfkhB8      17.13.11
# 18   6H3wVsceoS0      17.13.11
# 19   ohACdnWapcY      17.13.11
# 20   PRlmRnU9qts      17.13.11
# 21   V4Uuxg6jmbo      17.13.11
# 22   kzwfHumJyYc      17.13.11
# 23   JwboxqDylgg      17.13.11
# 24   7779JdxVAg0      17.13.11
# 25   wuf2KinLxZ8      17.13.11
# 26   WuTFI5qftCE      17.13.11
# 27   exMNBvwCfRY      17.13.11
# ...
